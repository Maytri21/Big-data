# %%
# !pip3 install pandas

# %%
# !pip3 install matplotlib

# %%
# !pip3 install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\MAYTRI\\Downloads\\IPL Ball-by-Ball 2008-2020.csv')
match_data = pd.read_csv('C:\\Users\\MAYTRI\\Downloads\\IPL Matches 2008-2020.csv')

match_data.head(8) #shows the details of top 8 entries
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
# 5  335987      Jaipur  2008-04-21       SR Watson
# 6  335988   Hyderabad  2008-04-22        V Sehwag
# 7  335989     Chennai  2008-04-23       ML Hayden
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
# 5                      Sawai Mansingh Stadium              0
# 6   Rajiv Gandhi International Stadium, Uppal              0
# ...

# %%
match_data["venue"].unique() #shows unique venues
# Out:
# array(['M Chinnaswamy Stadium',
#        'Punjab Cricket Association Stadium, Mohali', 'Feroz Shah Kotla',
#        'Wankhede Stadium', 'Eden Gardens', 'Sawai Mansingh Stadium',
#        'Rajiv Gandhi International Stadium, Uppal',
#        'MA Chidambaram Stadium, Chepauk', 'Dr DY Patil Sports Academy',
#        'Newlands', "St George's Park", 'Kingsmead', 'SuperSport Park',
#        'Buffalo Park', 'New Wanderers Stadium', 'De Beers Diamond Oval',
#        'OUTsurance Oval', 'Brabourne Stadium',
#        'Sardar Patel Stadium, Motera', 'Barabati Stadium',
#        'Vidarbha Cricket Association Stadium, Jamtha',
#        'Himachal Pradesh Cricket Association Stadium', 'Nehru Stadium',
#        'Holkar Cricket Stadium',
#        'Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium',
#        'Subrata Roy Sahara Stadium',
#        'Shaheed Veer Narayan Singh International Stadium',
#        'JSCA International Stadium Complex', 'Sheikh Zayed Stadium',
# ...

# %%
match_data["team2"].nunique() #shows the number of unique teams
# Out:
# 15

# %%
match_data["venue"].value_counts() #gives the count of how many matches are played on a venue
# Out:
# venue
# Eden Gardens                                            77
# Feroz Shah Kotla                                        74
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   65
# Rajiv Gandhi International Stadium, Uppal               64
# MA Chidambaram Stadium, Chepauk                         57
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Dubai International Cricket Stadium                     33
# Sheikh Zayed Stadium                                    29
# Maharashtra Cricket Association Stadium                 21
# Punjab Cricket Association IS Bindra Stadium, Mohali    21
# Sharjah Cricket Stadium                                 18
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# M.Chinnaswamy Stadium                                   15
# ...

# %%
match_data["toss_winner"].value_counts().head(3) #shows top three teams that won the toss
# Out:
# toss_winner
# Mumbai Indians           106
# Kolkata Knight Riders     98
# Chennai Super Kings       97
# Name: count, dtype: int64

# %%
match_data["toss_winner"].value_counts().head(3).index[0] #shows the team which won the most tosses
# Out:
# 'Mumbai Indians'

# %%
match_data["player_of_match"].value_counts() #counts which player has won how many player of the match
# Out:
# player_of_match
# AB de Villiers    23
# CH Gayle          22
# RG Sharma         18
# DA Warner         17
# MS Dhoni          17
#                   ..
# CV Varun           1
# Shivam Mavi        1
# R Tewatia          1
# PK Garg            1
# PJ Cummins         1
# Name: count, Length: 233, dtype: int64

# %%
match_data["city"].isnull().sum() # for each column of dataframe
# Out:
# np.int64(13)

# %%
print(match_data.isnull().sum()) #for all column of dataframe
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      4
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               4
# result               4
# result_margin       17
# eliminator           4
# method             797
# umpire1              0
# umpire2              0
# dtype: int64

# %%
match_data.dropna( subset="winner", inplace=True) #used to drop the null values in a column
match_data.isnull().sum()
# Out:
# id                   0
# city                13
# date                 0
# player_of_match      0
# venue                0
# neutral_venue        0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# winner               0
# result               0
# result_margin       13
# eliminator           0
# method             793
# umpire1              0
# umpire2              0
# dtype: int64

# %%
match_data['date']= pd.to_datetime(match_data['date']) #changes the string value of date to integer value
match_data['season']= match_data['date'].dt.year       #adding the season here

# %%
season_matches= match_data ['season'].value_counts().sort_index() #shows how many matches are played in a season
season_matches
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    72
# 2012    74
# 2013    76
# 2014    60
# 2015    57
# 2016    60
# 2017    59
# 2018    60
# 2019    59
# 2020    60
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
season_matches = match_data['season'].value_counts().sort_index()          #shows the values
plt.bar(season_matches.index, season_matches.values,color ='pink')         #for graph
plt.title("total matches played!!!!hurrraayyyyyyyy")                       #for title
plt.xlabel("year")
plt.ylabel("number of matches")
plt.grid(axis='y')                                                         #for making grids
plt.xticks(season_matches.index,rotation=45)                               #for tilting the values
# Out:
# ([<matplotlib.axis.XTick at 0x253bc509fd0>,
# ...
#  [Text(2008, 0, '2008'),
#   Text(2009, 0, '2009'),
#   Text(2010, 0, '2010'),
#   Text(2011, 0, '2011'),
#   Text(2012, 0, '2012'),
#   Text(2013, 0, '2013'),
#   Text(2014, 0, '2014'),
#   Text(2015, 0, '2015'),
#   Text(2016, 0, '2016'),
#   Text(2017, 0, '2017'),
#   Text(2018, 0, '2018'),
#   Text(2019, 0, '2019'),
#   Text(2020, 0, '2020')])

# %%
player_series=match_data['player_of_match'].value_counts()[0:5]      #pie chart
player_series.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
venue_teams_wins=match_data.groupby(['venue', 'winner']).size().unstack(fill_value=0)  #shows which team has played how many match in which venue
venue_teams_wins.loc['Buffalo Park']  #loc command is the only command that works on column name rather than index
# Out:
# winner
# Chennai Super Kings            1
# Deccan Chargers                0
# Delhi Capitals                 0
# Delhi Daredevils               1
# Gujarat Lions                  0
# Kings XI Punjab                0
# Kochi Tuskers Kerala           0
# Kolkata Knight Riders          0
# Mumbai Indians                 1
# Pune Warriors                  0
# Rajasthan Royals               0
# Rising Pune Supergiant         0
# Rising Pune Supergiants        0
# Royal Challengers Bangalore    0
# Sunrisers Hyderabad            0
# Name: Buffalo Park, dtype: int64

# %%
match_data.groupby(['venue', 'winner']).size().unstack(fill_value=0) #shows the details of the venue
# Out:
# winner                                              Chennai Super Kings  \
# venue
# Barabati Stadium                                                      0
# Brabourne Stadium                                                     1
# Buffalo Park                                                          1
# De Beers Diamond Oval                                                 1
# Dr DY Patil Sports Academy                                            3
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...                    2
# Dubai International Cricket Stadium                                   6
# Eden Gardens                                                          5
# Feroz Shah Kotla                                                      6
# Green Park                                                            0
# Himachal Pradesh Cricket Association Stadium                          1
# Holkar Cricket Stadium                                                0
# ...

# %%
team_venues=match_data['venue'].value_counts().head(5).index
venue_teams_wins=venue_teams_wins.loc[team_venues] #loc is a command used for column name and give all values associated to it
venue_teams_wins
venue_teams_wins.T.plot(kind='bar',stacked=True,figsize=(14,6),colormap='tab20') #stacked used for stacking values, figsize is size of x and y axis, colormap is used for giving style and gradient to background
plt.title('matches won by teams at top venues')
plt.xlabel('teams')
plt.ylabel('wins')
plt.legend(title='venue', bbox_to_anchor=(1.05,1),loc='upper left')  #used to make a box showing statistics of the graph, here loc is location, bbox is used to give size to legend
plt.tight_layout()
plt.show()

# %%
#Use deliveries data frame and find out year by year how many number of runs have we scored in each season.Now get the total no of runs score in each season by each team and make a line graph
match_data['date']= pd.to_datetime(match_data['date']) 
match_data['season']= match_data['date'].dt.year 
merged_df = pd.merge(df, match_data[['id','season']], left_on='id',right_on='id')  #merge is used to merge the files
season_team_runs = merged_df.groupby(['season', 'batting_team'])['total_runs'].sum().reset_index()  #reset_index is used for saving the calculated result into a clean dataframe

pivot_df = season_team_runs.pivot(index='season', columns='batting_team', values='total_runs')
plt.figure(figsize=(15, 8))
for team in pivot_df.columns:
    plt.plot(pivot_df.index, pivot_df[team], marker='o', label=team)  #converting data into matrix form
plt.title('Total Runs Scored by Each Team in Each IPL Season')
plt.xlabel('Season')
plt.ylabel('Total Runs')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Get the top five wicket keepers based on lbw and make a bar graph of it.
df.columns = df.columns.str.strip()

e=df[(df["dismissal_kind"]=='lbw') & (df['batsman'].notna())]
f=e.head(5)

print("Top 5 Wicketkeepers Based on LBW Dismissals:")
print(f)

plt.figure(figsize=(8, 6))
f.plot(kind='bar', color='yellow', edgecolor='black')
plt.title('Top 5 Wicketkeepers Based on LBW Dismissals in IPL')
plt.xlabel('Wicketkeeper (Fielder)')
plt.ylabel('Number of LBW Dismissals')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# Top 5 Wicketkeepers Based on LBW Dismissals:
#           id  inning  over  ball       batsman   non_striker       bowler  \
# 348   335983       1     7     1      MS Dhoni    MEK Hussey     JR Hopes
# 598   335984       1     7     4    DS Lehmann        M Kaif  MF Maharoof
# 956   335986       2     2     1    RT Ponting       WP Saha   WPUJC Vaas
# 1311  335987       1     8     6      JR Hopes  Yuvraj Singh     SK Warne
# 1358  335987       1    16     5  Yuvraj Singh     IK Pathan     SK Warne
#
#       batsman_runs  extra_runs  total_runs  non_boundary  is_wicket  \
# 348              0           0           0             0          1
# 598              0           0           0             0          1
# 956              0           0           0             0          1
# 1311             0           0           0             0          1
# 1358             0           0           0             0          1
#
#      dismissal_kind player_dismissed fielder extras_type  \
# ...

# %%
#Get the overall runs score by virat kohli in once in two in threes in fours and in sixes and make bar graph.
df.columns = df.columns.str.strip()
kohli_df = df[df['batsman'] == 'V Kohli']
run_counts = {
    'Ones': kohli_df[kohli_df['batsman_runs'] == 1].shape[0],
    'Twos': kohli_df[kohli_df['batsman_runs'] == 2].shape[0],
    'Threes': kohli_df[kohli_df['batsman_runs'] == 3].shape[0],
    'Fours': kohli_df[kohli_df['batsman_runs'] == 4].shape[0],
    'Sixes': kohli_df[kohli_df['batsman_runs'] == 6].shape[0],
}
pd.Series(run_counts).plot(kind='bar', color='orange', edgecolor='black', figsize=(8, 6))
plt.title('Virat Kohli - Run Type Distribution in IPL (2008–2020)')
plt.xlabel('Run Type')
plt.ylabel('Number of Times')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
#Find out each team how many number of matches won in 2016 and compare it to 2017,plot graph
match_data.columns = match_data.columns.str.strip()

match_data['date'] = pd.to_datetime(match_data['date'])
match_data['season'] = match_data['date'].dt.year

match_wins = match_data[match_data['season'].isin([2016, 2017])]
wins_by_team_year = match_wins.groupby(['season', 'winner']).size().unstack(fill_value=0)

wins_by_team_year = wins_by_team_year.transpose() #to transpose x and y axis

wins_by_team_year.plot(kind='bar', figsize=(12, 6), color=['yellow','pink'])
plt.title('Matches Won by Each Team in 2016 vs 2017')
plt.xlabel('Team')
plt.ylabel('Matches Won')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)  #alpha is used for width
plt.tight_layout()
plt.show()
